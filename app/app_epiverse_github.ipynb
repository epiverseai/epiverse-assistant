# %% [markdown]
# ![101338582.png](data:image/png;base64,...)
#
# # **Epiverse Assistant**
#
# En el siguiente cuaderno podrá encontrar:
#
# - Cómo configurar el aplicativo
# - Cómo poder usar el aplicativo
# - Aplicativo a usar

# %% [markdown]
# # **¿Cómo configuro el aplicativo?**

# %% [markdown]
# A continuación se presenta un paso a paso de cómo configurar el aplicativo.
#
# 1. Ir a la sección aplicativo y presionar el botón de _play_ ▶️
#
# ![image.png](data:image/png;base64,...)
#
# 2. Posteriormente se debe esperar a que cargue hasta que salga el siguiente menseje:
#
# ![image.png](data:image/png;base64,...)
#
# 3. Una vez observe el mensaje debe presionar el último enlace que aparece, en el caso de este ejemplo sería:
#
# ![image.png](data:image/png;base64,...)
#
# 4. Al presionar lo redigirá a la siguiente página:
#
# ![image.png](data:image/png;base64,...)
#
# Allí deberá ingresar dentro de `Tunnel Password` la contraseña que encuentra en el siguente sitio:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Presione `Click to Submit`
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Espere hasta que la aplicación termine de cargar
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Una vez observe la siguiente pantalla, la aplicación se encuentra lista para usar 😊
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **¿Cómo uso el aplicativo?**

# %% [markdown]
# Puedes seleccionar sobre qué tema hacer las preguntas, seleccionando una opción en la barra izquierda.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Realiza la pregunta cuya respuesta quieres aprender o verificar en la barra inferior y luego presiona `enter` para enviarla al assistente
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Espera que el assistente procese tu pregunta y genere la respuesta
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Y listo ✅ puedes usar preguntar cuantas veces quieras
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Aplicativo**

# %% [markdown]
# Por favor presione el símbolo `▶️` abajo a mano izquierda después de ingresar tu token de Hugging Face

# %%
#Ingresa tus credenciales de Hugging Face (reemplaza el texto "tu_token_hugging_face_aqui" por tu token de Hugging Face)
clave_hugging_face = "tu_token_hugging_face_aqui"

# %% [markdown]
# Ejecución del código (Por favor presione el símbolo `▶️` abajo a mano izquierda)

# %%
# !git clone https://github.com/epiverseai/epiverse-assistant.git
# !pip install -r epiverse-assistant/requirements.txt --quiet
# !echo -e "HFT={clave_hugging_face}" > epiverse-assistant/.env
# !echo -e "\n"
# !printf "#%.0s" {1..63}
# !echo -e "\n   Contraseña/Enpoint IP para localtunnel es: $(wget -qO- ipv4.icanhazip.com)   "
# !printf "#%.0s" {1..63}
# !echo -e "\n"
# !streamlit run "epiverse-assistant/1_🤓_Epiverse-Sivirep (Asistente Codigo).py" & npx localtunnel --port 8501
